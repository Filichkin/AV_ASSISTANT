# %%
import pandas as pd

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# %%
df = pd.read_excel('products.xlsx')

print(df.shape)

df.sample(5)
# Out:
# (3861, 21)
#                                    Группы  \
# 2697  Товары интернет-магазинов/Пробук.рф
# 2972  Товары интернет-магазинов/Пробук.рф
# 1751  Товары интернет-магазинов/Пробук.рф
# 1394  Товары интернет-магазинов/Пробук.рф
# 2165  Товары интернет-магазинов/Пробук.рф
#
#                                       UUID    Тип       Код  \
# 2697  f4b06404-a2dc-11ec-0a80-02db0024a65d  Товар    1156.0
# 2972  703dbef9-0a20-11f0-0a80-15c200085a59  Товар  266494.0
# 1751  ade55fa2-1000-11ec-0a80-05c500141283  Товар     598.0
# 1394  4331b74f-5897-11ee-0a80-04080014fc0e  Товар    2564.0
# 2165  388a256e-43f6-11ed-0a80-017d00145c49  Товар    1644.0
#
#                                                                                                                                 Наименование  \
# 2697                                                                                                            Ноутбук Acer Extensa 215-22G
# 2972      13,3" Уцененный Ноутбук HP Elite x360 830 G9 2in1 (1920x1080, Intel Core i5-1245U, RAM 16ГБ, SSD 256ГБ, Intel Iris XE, Win 11 Pro)
# 1751                                                                                                             Ноутбук Dell Latitude E3470
# 1394              12.5" Ноутбук Lenovo ThinkPad x280 (1920x1080, Intel Core i5-8350U, RAM 8ГБ ,SSD 256ГБ, Intel UHD Graphics 620, Win 10Pro)
# 2165  13.3" Ноутбук Apple MacBook Pro 13 2017 Space Gray (2560x1600, Intel Core i5-7267U, RAM 8ГБ, SSD 128ГБ, Iris Plus Graphics 640, MacOS)
#
#       Артикул Единица измерения      Цена Валюта (Цена продажи)  \
# 2697    01156                шт  45000,00                   руб
# 2972  0266494                шт  50500,00                   руб
# 1751    00598                шт  30000,00                   руб
# 1394    02564                шт  25500,00                   руб
# 2165    01644                шт  35500,00                   руб
#
#      Неснижаемый остаток  Неснижаемый остаток Одинаковый на всех складах  \
# 2697                 руб                                             NaN
# 2972                 руб                                             NaN
# 1751                 руб                                             NaN
# 1394                 руб                                             NaN
# 2165                 руб                                             NaN
#
#       Неснижаемый остаток для склада Milwaukee  \
# 2697                                       NaN
# 2972                                       NaN
# 1751                                       NaN
# 1394                                       NaN
# 2165                                       NaN
#
#       Неснижаемый остаток для склада Аксессуары  \
# 2697                                        NaN
# 2972                                        NaN
# 1751                                        NaN
# 1394                                        NaN
# 2165                                        NaN
#
#       Неснижаемый остаток для склада Оптовый склад  \
# 2697                                           NaN
# 2972                                           NaN
# 1751                                           NaN
# 1394                                           NaN
# 2165                                           NaN
#
#       Неснижаемый остаток для склада Основной склад  \
# 2697                                            NaN
# 2972                                            NaN
# 1751                                            NaN
# 1394                                            NaN
# 2165                                            NaN
#
#       Неснижаемый остаток для склада Склад Мастерская  \
# 2697                                              NaN
# 2972                                              NaN
# 1751                                              NaN
# 1394                                              NaN
# 2165                                              NaN
#
#       Неснижаемый остаток для склада Склад Питер  \
# 2697                                         NaN
# 2972                                         NaN
# 1751                                         NaN
# 1394                                         NaN
# 2165                                         NaN
#
#       Неснижаемый остаток для склада Торговая площадка  Штрихкод EAN13  \
# 2697                                               NaN             NaN
# 2972                                               NaN             NaN
# 1751                                               NaN             NaN
# 1394                                               NaN             NaN
# 2165                                               NaN             NaN
#
#       Штрихкод EAN8  Штрихкод Code128
# 2697   2.000000e+12               NaN
# 2972   2.000000e+12               NaN
# 1751   2.000000e+12               NaN
# 1394   2.000000e+12               NaN
# 2165   2.000000e+12               NaN

# %%
df.columns = [
    'groups',
    'uuid',
    'type',
    'code',
    'name',
    'sku',
    'unit',
    'price',
    'currency',
    'min_stock',
    'min_stock_same_across_warehouses',
    'min_stock_milwaukee',
    'min_stock_accessories',
    'min_stock_wholesale',
    'min_stock_main',
    'min_stock_workshop',
    'min_stock_spb',
    'min_stock_marketplace',
    'ean13_barcode',
    'ean8_barcode',
    'code128_barcode'
]

# %%
df.head(2)
# Out:
#                                 groups                                  uuid  \
# 0  Товары интернет-магазинов/Пробук.рф  000e19dd-5e72-11ed-0a80-0f5a004366b3
# 1                                  NaN  bc967ec4-7526-11ec-0a80-042a000aeedd
#
#     type    code                              name    sku unit     price  \
# 0  Товар  1682.0  Ноутбук Lenovo Thinkpad P1 Gen 3  01682   шт    100500
# 1  Товар   937.0         Ноутбук Acer 5250-e302g32  00937   шт  10000,00
#
#   currency min_stock  min_stock_same_across_warehouses  min_stock_milwaukee  \
# 0      руб       руб                               NaN                  NaN
# 1      руб       руб                               NaN                  NaN
#
#    min_stock_accessories  min_stock_wholesale  min_stock_main  \
# 0                    NaN                  NaN             NaN
# 1                    NaN                  NaN             NaN
#
#    min_stock_workshop  min_stock_spb  min_stock_marketplace  ean13_barcode  \
# 0                 NaN            NaN                    NaN            NaN
# 1                 NaN            NaN                    NaN            NaN
#
#    ean8_barcode  code128_barcode
# 0  2.000000e+12              NaN
# 1  2.000000e+12              NaN

# %%
df.groups.unique()
# Out:
# array(['Товары интернет-магазинов/Пробук.рф', nan,
#        'Каталог/Недорогие ноутбуки',
#        'Товары интернет-магазинов/probookrf.ru',
#        'Каталог/Ультрабуки бизнес серии',
#        'Каталог/Новые витринные образцы', 'Каталог/Защищенные ноутбуки',
#        'Каталог/Моноблоки', 'Товары интернет-магазинов/WB',
#        'Каталог/MacBook', 'Товары интернет-магазинов/nbkatalog',
#        'Товары интернет-магазинов/probookrf.ruv',
#        'Товары интернет-магазинов', 'Каталог/Мониторы и принтеры'],
#       dtype=object)
